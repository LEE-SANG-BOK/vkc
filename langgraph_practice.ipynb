# %% [markdown]
# # LangGraph 실습 노트북
#
# 이 노트북은 LangGraph의 기본 사용법을 실습하기 위한 예제입니다.

# %%
# 필수 패키지 설치 (최초 1회만 실행)
# !pip install langgraph python-dotenv

# %%
# 환경 변수 로드
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv('API_KEY')
print(f'Loaded API_KEY: {api_key[:8]}...')

# %%
# LangGraph 기본 예제 (여기에 LangGraph 실습 코드를 추가하세요)
# 예시: import langgraph
import langgraph
print('LangGraph 버전:', langgraph.__version__)
